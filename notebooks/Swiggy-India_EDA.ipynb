# %% [markdown]
# ## Swiggy India Exploratory Data Analysis

# %% [markdown]
# This is an EDA project about a food delivery app named Swiggy.
# Data is taken from kaggle to keep EDA practice as real as possible.

# %% [markdown]
# 1. We will import all the required libraries for the analysis.

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# 2. Importing dataset from csv file and print first 5 records using head function in pandas to analyse the data and clean it accordingly.

# %%
data = pd.read_csv(r"..\data\raw\swiggy.csv")
data.head
# Out:
# <bound method NDFrame.head of             id                      name      city rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar     --  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar    4.4      50+ ratings
# 2       158203         theka coffee desi    Abohar    3.8     100+ ratings
# 3       187912                 Singh Hut    Abohar    3.7      20+ ratings
# 4       543530             GRILL MASTERS    Abohar     --  Too Few Ratings
# ...        ...                       ...       ...    ...              ...
# 148536  553122          The Food Delight  Yavatmal     --  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     --  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal     --  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal     --  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal     --  Too Few Ratings
#
# ...

# %% [markdown]
# After analysing the data few functions are made to clean the data in the above dataset

# %% [markdown]
# 3. We have created a seprate file of functions to clean the data in data_cleaning.py in src directory. This will help us to increase readability of the code in this notebook.
# Now, we will add path of directory to the system for access to functions.
# List of functions created in data_cleaning.py are:-
#     1. clean_column_names
#     2. clean_rating_column
#     3. clean_rating_count

# %%
import sys
sys.path.append('../src')

# %% [markdown]
# 4. Apply created functions to the data.

# %%
from data_cleaning import clean_column_names
from data_cleaning import clean_rating_column
from data_cleaning import clean_rating_count
clean_column_names(data)
clean_rating_column(data)
clean_rating_count(data)
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     NaN           NaN
# 1       531342         Janta Sweet House    Abohar     4.4          50.0
# 2       158203         theka coffee desi    Abohar     3.8         100.0
# 3       187912                 Singh Hut    Abohar     3.7          20.0
# 4       543530             GRILL MASTERS    Abohar     NaN           NaN
# ...        ...                       ...       ...     ...           ...
# 148536  553122          The Food Delight  Yavatmal     NaN           NaN
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     NaN           NaN
# 148538  559435           Cafe Bella Ciao  Yavatmal     NaN           NaN
# 148539  418989               GRILL ZILLA  Yavatmal     NaN           NaN
# 148540  447770            Lazeez kitchen  Yavatmal     NaN           NaN
#
#          cost                     cuisine          lic_no  \
# ...

# %% [markdown]
# 5. Removed unwanted features to reduce complexity of data

# %%
data = data.drop(columns=["link", "address", "menu","lic_no"])
data.head()
# Out:
#        id               name    city  rating  rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar     NaN           NaN  ₹ 200
# 1  531342  Janta Sweet House  Abohar     4.4          50.0  ₹ 200
# 2  158203  theka coffee desi  Abohar     3.8         100.0  ₹ 100
# 3  187912          Singh Hut  Abohar     3.7          20.0  ₹ 250
# 4  543530      GRILL MASTERS  Abohar     NaN           NaN  ₹ 250
#
#                       cuisine
# 0            Beverages,Pizzas
# 1               Sweets,Bakery
# 2                   Beverages
# 3            Fast Food,Indian
# 4  Italian-American,Fast Food

# %% [markdown]
# 6. Filling nan values of rating and rating_count to 0

# %%
data["rating"] = data["rating"].fillna(0)
data["rating_count"] = data["rating_count"].fillna(0)
data.head()
# Out:
#        id               name    city  rating  rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar     0.0           0.0  ₹ 200
# 1  531342  Janta Sweet House  Abohar     4.4          50.0  ₹ 200
# 2  158203  theka coffee desi  Abohar     3.8         100.0  ₹ 100
# 3  187912          Singh Hut  Abohar     3.7          20.0  ₹ 250
# 4  543530      GRILL MASTERS  Abohar     0.0           0.0  ₹ 250
#
#                       cuisine
# 0            Beverages,Pizzas
# 1               Sweets,Bakery
# 2                   Beverages
# 3            Fast Food,Indian
# 4  Italian-American,Fast Food

# %% [markdown]
# 7. Now the data is cleaned fully so we will export the data and visualize it to extact usefull insights form the data.

# %%
# data.to_csv('../data/processed/swiggy_cleaned.csv', index=False)

# %% [markdown]
# 8. After the data is cleaned from our side lets check summary of the dataset.
# This will help to check weather the data is cleaned sucessfully without any problem left.

# %%
# data.info()
data.describe()
# Out:
#                   id         rating   rating_count
# count  148541.000000  148541.000000  148541.000000
# mean   363466.378912       1.610866      35.608680
# std    167890.977174       1.940654      88.172843
# min       211.000000       0.000000       0.000000
# 25%    233320.000000       0.000000       0.000000
# 50%    412628.000000       0.000000       0.000000
# 75%    502223.000000       3.800000      20.000000
# max    581031.000000       5.000000     500.000000

# %% [markdown]
# 9. Here we can see that the cost column is not showing its statistical summary.
#     Problem with it is, that cost column is not in int or float it is considered as string as showen with data.info method.

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 148541 entries, 0 to 148540
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            148541 non-null  int64
#  1   name          148455 non-null  str
#  2   city          148541 non-null  str
#  3   rating        148541 non-null  float64
#  4   rating_count  148541 non-null  float64
#  5   cost          148410 non-null  str
#  6   cuisine       148442 non-null  str
# dtypes: float64(2), int64(1), str(4)
# memory usage: 7.9 MB

# %% [markdown]
# 10. To handle this we will need to convert str to int or float.
#     we will create a function in our data_cleaning.py

# %%
#Importing the function and using it 
from data_cleaning import cost_str_to_float
cost_str_to_float(data)
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     0.0           0.0
# 1       531342         Janta Sweet House    Abohar     4.4          50.0
# 2       158203         theka coffee desi    Abohar     3.8         100.0
# 3       187912                 Singh Hut    Abohar     3.7          20.0
# 4       543530             GRILL MASTERS    Abohar     0.0           0.0
# ...        ...                       ...       ...     ...           ...
# 148536  553122          The Food Delight  Yavatmal     0.0           0.0
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     0.0           0.0
# 148538  559435           Cafe Bella Ciao  Yavatmal     0.0           0.0
# 148539  418989               GRILL ZILLA  Yavatmal     0.0           0.0
# 148540  447770            Lazeez kitchen  Yavatmal     0.0           0.0
#
#          cost                     cuisine
# 0       200.0            Beverages,Pizzas
# ...

# %%
data.describe()
# Out:
#                   id         rating   rating_count           cost
# count  148541.000000  148541.000000  148541.000000  148410.000000
# mean   363466.378912       1.610866      35.608680     287.600714
# std    167890.977174       1.940654      88.172843     796.730688
# min       211.000000       0.000000       0.000000       1.000000
# 25%    233320.000000       0.000000       0.000000     200.000000
# 50%    412628.000000       0.000000       0.000000     250.000000
# 75%    502223.000000       3.800000      20.000000     300.000000
# max    581031.000000       5.000000     500.000000  300350.000000

# %% [markdown]
# 11. Now the problem is that cost count is less then the actual count, means cost contains null values.

# %%
data['cost']=data['cost'].fillna(data['cost'].mean)
data.describe()
# Out:
#                   id         rating   rating_count
# count  148541.000000  148541.000000  148541.000000
# mean   363466.378912       1.610866      35.608680
# std    167890.977174       1.940654      88.172843
# min       211.000000       0.000000       0.000000
# 25%    233320.000000       0.000000       0.000000
# 50%    412628.000000       0.000000       0.000000
# 75%    502223.000000       3.800000      20.000000
# max    581031.000000       5.000000     500.000000

# %% [markdown]
# 12. Export the file

# %%
data.to_csv('../data/processed/swiggy_cleaned.csv', index=False)
